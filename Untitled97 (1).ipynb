# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import google.generativeai as genai
import time
import json

# API Keys
POLYGON_API_KEY = "our-api-key"
GEMINI_API_KEY = "your-api-key"
# Configure Gemini AI
genai.configure(api_key=GEMINI_API_KEY)
model = genai.GenerativeModel('gemini-2.0-flash')

# Currency pairs to analyze
CURRENCY_PAIRS = ["USDJPY", "EURUSD", "GBPUSD", "AUDUSD"]

class ForexTrader:
    def __init__(self):
        self.data = {}
        self.analysis = {}
        self.recommendations = {}
        self.risk_management = {}

    def fetch_forex_data(self, symbol, timespan="day", multiplier=1, from_date=None, to_date=None):
        """Fetch historical forex data from Alpha Vantage"""
        if from_date is None:
            from_date = (datetime.now() - timedelta(days=60)).strftime('%Y-%m-%d')
        if to_date is None:
            to_date = datetime.now().strftime('%Y-%m-%d')

        ticker = f"C:{symbol}"
        url = f"https://api.polygon.io/v2/aggs/ticker/{ticker}/range/{multiplier}/{timespan}/{from_date}/{to_date}?adjusted=true&sort=asc&limit=120&apiKey={ALPHA_VANTAGE_API_KEY}"

        response = requests.get(url)

        if response.status_code == 200:
            data = response.json()
            if 'results' in data and data['results']:
                # Convert to DataFrame
                df = pd.DataFrame(data['results'])

                # Rename columns to more readable format
                df = df.rename(columns={
                    'o': 'open',
                    'h': 'high',
                    'l': 'low',
                    'c': 'close',
                    'v': 'volume',
                    't': 'timestamp'
                })

                # Convert timestamp to datetime
                df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')

                # Calculate additional technical indicators
                self.add_technical_indicators(df)

                self.data[symbol] = df
                print(f"Successfully fetched data for {symbol}")
                return df
            else:
                print(f"No results found for {symbol}")
                return None
        else:
            print(f"Error fetching data for {symbol}: {response.status_code}")
            print(response.text)
            return None

    def add_technical_indicators(self, df):
        """Add technical indicators to the dataframe"""
        # Moving Averages
        df['SMA_20'] = df['close'].rolling(window=20).mean()
        df['SMA_50'] = df['close'].rolling(window=50).mean()
        df['EMA_12'] = df['close'].ewm(span=12, adjust=False).mean()
        df['EMA_26'] = df['close'].ewm(span=26, adjust=False).mean()

        # MACD
        df['MACD'] = df['EMA_12'] - df['EMA_26']
        df['MACD_Signal'] = df['MACD'].ewm(span=9, adjust=False).mean()
        df['MACD_Hist'] = df['MACD'] - df['MACD_Signal']

        # RSI (Relative Strength Index)
        delta = df['close'].diff()
        gain = delta.where(delta > 0, 0)
        loss = -delta.where(delta < 0, 0)
        avg_gain = gain.rolling(window=14).mean()
        avg_loss = loss.rolling(window=14).mean()
        rs = avg_gain / avg_loss
        df['RSI'] = 100 - (100 / (1 + rs))

        # Bollinger Bands
        df['BB_Middle'] = df['close'].rolling(window=20).mean()
        df['BB_Std'] = df['close'].rolling(window=20).std()
        df['BB_Upper'] = df['BB_Middle'] + (df['BB_Std'] * 2)
        df['BB_Lower'] = df['BB_Middle'] - (df['BB_Std'] * 2)

        # Average True Range (ATR)
        high_low = df['high'] - df['low']
        high_close_prev = abs(df['high'] - df['close'].shift(1))
        low_close_prev = abs(df['low'] - df['close'].shift(1))
        true_range = pd.concat([high_low, high_close_prev, low_close_prev], axis=1).max(axis=1)
        df['ATR'] = true_range.rolling(window=14).mean()

        # Stochastic Oscillator
        low_14 = df['low'].rolling(window=14).min()
        high_14 = df['high'].rolling(window=14).max()
        df['%K'] = 100 * ((df['close'] - low_14) / (high_14 - low_14))
        df['%D'] = df['%K'].rolling(window=3).mean()

        return df

    def identify_patterns(self, symbol):
        """Use Gemini AI to identify patterns in the forex data"""
        if symbol not in self.data or self.data[symbol] is None:
            print(f"No data available for {symbol}")
            return None

        df = self.data[symbol].copy()

        # Prepare the last 10 days of data for analysis
        recent_data = df.tail(10).copy()
        recent_data_json = recent_data[['timestamp', 'open', 'high', 'low', 'close', 'volume',
                                      'SMA_20', 'SMA_50', 'RSI', 'MACD', 'MACD_Signal',
                                      '%K', '%D', 'ATR']].to_json(orient='records', date_format='iso')

        # Calculate key statistics
        current_price = df['close'].iloc[-1]
        sma_20 = df['SMA_20'].iloc[-1]
        sma_50 = df['SMA_50'].iloc[-1]
        rsi = df['RSI'].iloc[-1]
        macd = df['MACD'].iloc[-1]
        macd_signal = df['MACD_Signal'].iloc[-1]
        stoch_k = df['%K'].iloc[-1]
        stoch_d = df['%D'].iloc[-1]

        # Prepare a prompt for Gemini AI
        prompt = f"""
        Analyze the following forex data for {symbol} and identify trading patterns, potential entry/exit points,
        and risk management strategies. Provide a detailed analysis and trading recommendation.

        Current Technical Indicators:
        - Current Price: {current_price:.4f}
        - SMA 20: {sma_20:.4f}
        - SMA 50: {sma_50:.4f}
        - RSI (14): {rsi:.2f}
        - MACD: {macd:.4f}
        - MACD Signal: {macd_signal:.4f}
        - Stochastic %K: {stoch_k:.2f}
        - Stochastic %D: {stoch_d:.2f}

        Based on this data:
        1. Identify any recognizable chart patterns (e.g., head and shoulders, double top/bottom, flags, etc.)
        2. Suggest an appropriate trading strategy (trend following, mean reversion, breakout)
        3. Provide entry point recommendations with specific price levels
        4. Recommend stop loss placement (in pips or price)
        5. Provide take profit targets (in pips or price)
        6. Estimate risk-reward ratio
        7. Suggest position sizing based on 2% max risk per trade

        Your analysis should be clear, quantitative, and actionable, focused on the next 1-5 trading days.
        """

        try:
            # Query Gemini AI
            response = model.generate_content(prompt)
            analysis_text = response.text

            # Store the analysis
            self.analysis[symbol] = analysis_text

            # Extract recommendations using another Gemini query
            recommendation_prompt = f"""
            Based on the following forex analysis for {symbol}, extract the key trading recommendations
            in a structured format. Return your response as a JSON object with the following fields:

            Analysis: {analysis_text}

            Format:
            {{
                "recommendation": "BUY" or "SELL" or "NEUTRAL",
                "strategy": "brief description of strategy",
                "entry_price": numerical value,
                "stop_loss": numerical value,
                "take_profit": numerical value,
                "risk_reward_ratio": numerical value,
                "position_sizing_percentage": numerical value,
                "timeframe": "short-term/medium-term/long-term",
                "confidence": "low/medium/high"
            }}

            Provide only the JSON object with no additional text.
            """

            recommendation_response = model.generate_content(recommendation_prompt)
            recommendation_text = recommendation_response.text

            # Clean up the response text to extract just the JSON part
            recommendation_text = recommendation_text.strip()
            if "```json" in recommendation_text:
                recommendation_text = recommendation_text.split("```json")[1].split("```")[0].strip()
            elif "```" in recommendation_text:
                recommendation_text = recommendation_text.split("```")[1].strip()

            # Parse JSON
            recommendation_json = json.loads(recommendation_text)

            # Validate recommendation data
            required_fields = ['recommendation', 'strategy', 'entry_price',
                             'stop_loss', 'take_profit', 'risk_reward_ratio',
                             'position_sizing_percentage', 'timeframe', 'confidence']

            for field in required_fields:
                if field not in recommendation_json:
                    print(f"Warning: Missing field {field} in recommendation for {symbol}")
                    recommendation_json[field] = None
                elif recommendation_json[field] is None:
                    print(f"Warning: Null value for field {field} in recommendation for {symbol}")

            self.recommendations[symbol] = recommendation_json

            return analysis_text

        except json.JSONDecodeError as e:
            print(f"Error parsing JSON recommendation for {symbol}: {e}")
            print("Original response:")
            print(recommendation_text)
            return f"Error: Failed to parse recommendation - {e}"
        except Exception as e:
            print(f"Error analyzing {symbol} with Gemini AI: {e}")
            return f"Error: {e}"

    def generate_risk_management_plan(self):
        """Generate overall risk management plan using Gemini AI"""
        if not self.recommendations:
            print("No recommendations available for risk management plan")
            return None

        # Prepare a summary of recommendations
        recommendations_summary = ""
        for symbol, rec in self.recommendations.items():
            recommendations_summary += f"{symbol}: {rec.get('recommendation', 'N/A')} - Entry: {rec.get('entry_price', 'N/A')}, SL: {rec.get('stop_loss', 'N/A')}, TP: {rec.get('take_profit', 'N/A')}\n"

        # Prepare a prompt for Gemini AI
        prompt = f"""
        Based on the following forex trading recommendations, create a comprehensive risk management plan.
        The plan should detail how to manage multiple positions across different currency pairs,
        addressing portfolio exposure, correlation risk, and overall risk limits.

        Current Recommendations:
        {recommendations_summary}

        Please provide:
        1. Maximum portfolio risk percentage (total capital at risk)
        2. Maximum correlated exposure (max percentage in correlated pairs)
        3. Position sizing rules with examples
        4. Criteria for adjusting stop losses
        5. Rules for partial profit-taking
        6. Criteria for exiting all positions (market conditions)
        7. Daily/weekly loss limits that would trigger trading pause
        8. Rules for scaling in/out of positions

        Important Points :
        **PNP STRATEGY Forex Pairs Use 200EMA on a 5min Timeframe with default indicator setting
        **Use 200EMA on a 5min Timeframe with 15Min


        1. Look for specific patterns
        a. Double Tops/Bottoms (With proper V shape in the
        center)
        b. Head & Shoulders/Inverted HNS
        2. Entry timing: 10Am to 10 Pm.
        3. Use both 5 Min & 15 Min 200EMA on the 5-minute chart.
        4. For Head & Shoulders only enter trades with DCC
        Confirmation or 1 big candle compared to previous 10 candles.
        5. Don't take trades if the 200EMA of 5Min or 15Min timeframe is near to our entry point showing the RiskReward Ratio (RRR) below 1:1.5.
        6. Aim for a minimum Risk-Reward Ratio of 1:1.5 or a logical target, Aim for 1:2 if no price action level nearby, Max Stoploss: 0.30%.
        7. Double Tops/Bottoms & Head & Shoulders Should only form on the EMA.
        8. We will avoid entry if the entry candle is bigger than 0.25%.
        9. Minimum 7-8 Candles required in both the shoulders in case of H&S, INV H&S.
        10. We will avoid entry if the recent high or low is within 50% of our overall target.


        Format your response as a structured plan with clear rules and guidelines.
        """

        try:
            # Query Gemini AI
            response = model.generate_content(prompt)
            risk_plan = response.text

            # Store the risk management plan
            self.risk_management['overall_plan'] = risk_plan

            return risk_plan

        except Exception as e:
            print(f"Error generating risk management plan with Gemini AI: {e}")
            return f"Error: {e}"

    def plot_chart(self, symbol):
        """Plot a chart with technical indicators for the given symbol"""
        if symbol not in self.data or self.data[symbol] is None:
            print(f"No data available for {symbol}")
            return

        df = self.data[symbol].copy()

        # Create a figure with 3 subplots
        fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(14, 12), gridspec_kw={'height_ratios': [3, 1, 1]})

        # Main chart with price and moving averages
        ax1.plot(df['timestamp'], df['close'], label='Close Price', linewidth=2)
        ax1.plot(df['timestamp'], df['SMA_20'], label='SMA 20', linestyle='--', alpha=0.8)
        ax1.plot(df['timestamp'], df['SMA_50'], label='SMA 50', linestyle='--', alpha=0.8)
        ax1.plot(df['timestamp'], df['BB_Upper'], 'k--', alpha=0.3)
        ax1.plot(df['timestamp'], df['BB_Lower'], 'k--', alpha=0.3)
        ax1.fill_between(df['timestamp'], df['BB_Upper'], df['BB_Lower'], alpha=0.1, color='gray')

        # Add buy/sell annotations if available
        if symbol in self.recommendations:
            rec = self.recommendations[symbol]

            # Only plot if we have valid recommendation data
            if all(key in rec for key in ['recommendation', 'entry_price']) and rec['entry_price'] is not None:
                try:
                    last_date = df['timestamp'].iloc[-1]
                    price = float(rec['entry_price'])
                    action = rec['recommendation']
                    color = 'green' if action == "BUY" else 'red' if action == "SELL" else 'gray'

                    ax1.annotate(f"{action} @ {price:.4f}",
                                xy=(last_date, price),
                                xytext=(10, 10),
                                textcoords="offset points",
                                arrowprops=dict(arrowstyle="->", color=color),
                                color=color,
                                fontsize=10,
                                bbox=dict(boxstyle="round,pad=0.3", fc="white", ec=color, lw=1))

                    # Add stop loss line if available and valid
                    if 'stop_loss' in rec and rec['stop_loss'] is not None:
                        try:
                            sl_price = float(rec['stop_loss'])
                            ax1.axhline(y=sl_price, color='red', linestyle='--', alpha=0.7, linewidth=1.5)
                            ax1.annotate(f"SL: {sl_price:.4f}",
                                        xy=(last_date, sl_price),
                                        xytext=(-80, -15),
                                        textcoords="offset points",
                                        color='red',
                                        fontsize=9)
                        except (ValueError, TypeError):
                            print(f"Invalid stop loss value for {symbol}: {rec['stop_loss']}")

                    # Add take profit line if available and valid
                    if 'take_profit' in rec and rec['take_profit'] is not None:
                        try:
                            tp_price = float(rec['take_profit'])
                            ax1.axhline(y=tp_price, color='green', linestyle='--', alpha=0.7, linewidth=1.5)
                            ax1.annotate(f"TP: {tp_price:.4f}",
                                        xy=(last_date, tp_price),
                                        xytext=(-80, 10),
                                        textcoords="offset points",
                                        color='green',
                                        fontsize=9)
                        except (ValueError, TypeError):
                            print(f"Invalid take profit value for {symbol}: {rec['take_profit']}")

                except (ValueError, TypeError) as e:
                    print(f"Error plotting recommendation for {symbol}: {e}")

        ax1.set_title(f'{symbol} Price Chart with Technical Indicators', fontsize=14, pad=20)
        ax1.set_ylabel('Price', fontsize=10)
        ax1.legend(loc='upper left', fontsize=9)
        ax1.grid(True, alpha=0.3)

        # MACD subplot
        ax2.plot(df['timestamp'], df['MACD'], label='MACD', color='blue', linewidth=1)
        ax2.plot(df['timestamp'], df['MACD_Signal'], label='Signal Line', color='orange', linewidth=1)
        ax2.bar(df['timestamp'], df['MACD_Hist'], alpha=0.5, label='Histogram', color=np.where(df['MACD_Hist'] >= 0, 'green', 'red'))
        ax2.axhline(y=0, color='black', linestyle='-', alpha=0.3)
        ax2.set_ylabel('MACD', fontsize=10)
        ax2.legend(loc='upper left', fontsize=9)
        ax2.grid(True, alpha=0.3)

        # RSI subplot
        ax3.plot(df['timestamp'], df['RSI'], label='RSI', color='purple', linewidth=1)
        ax3.axhline(y=70, color='red', linestyle='--', alpha=0.3)
        ax3.axhline(y=30, color='green', linestyle='--', alpha=0.3)
        ax3.fill_between(df['timestamp'], 70, 30, alpha=0.1, color='gray')
        ax3.set_ylabel('RSI', fontsize=10)
        ax3.set_xlabel('Date', fontsize=10)
        ax3.legend(loc='upper left', fontsize=9)
        ax3.grid(True, alpha=0.3)

        plt.tight_layout()
        plt.savefig(f"{symbol}_chart.png", dpi=300, bbox_inches='tight')
        plt.close()

        print(f"Chart for {symbol} has been saved as {symbol}_chart.png")

    def run_full_analysis(self):
        """Run a full analysis on all currency pairs"""
        # Fetch data for all currency pairs
        for pair in CURRENCY_PAIRS:
            self.fetch_forex_data(pair)
            time.sleep(1)  # Avoid API rate limits

        # Analyze patterns for all pairs
        for pair in CURRENCY_PAIRS:
            if pair in self.data and self.data[pair] is not None:
                print(f"\nAnalyzing patterns for {pair}...")
                analysis = self.identify_patterns(pair)
                if analysis:
                    print(f"Analysis for {pair} completed.")
                time.sleep(2)  # Avoid API rate limits

        # Generate risk management plan
        print("\nGenerating risk management plan...")
        risk_plan = self.generate_risk_management_plan()
        if risk_plan:
            print("Risk management plan generated.")

        # Generate charts
        for pair in CURRENCY_PAIRS:
            if pair in self.data and self.data[pair] is not None:
                self.plot_chart(pair)

        # Print summary
        self.print_summary()

    def print_summary(self):
        """Print a summary of all analysis and recommendations"""
        print("\n" + "="*80)
        print("FOREX TRADING STRATEGY SUMMARY")
        print("="*80)

        for pair in CURRENCY_PAIRS:
            if pair in self.recommendations:
                rec = self.recommendations[pair]
                print(f"\n{pair} RECOMMENDATION:")
                print(f"Action: {rec.get('recommendation', 'N/A')}")
                print(f"Strategy: {rec.get('strategy', 'N/A')}")
                print(f"Entry Price: {rec.get('entry_price', 'N/A')}")
                print(f"Stop Loss: {rec.get('stop_loss', 'N/A')}")
                print(f"Take Profit: {rec.get('take_profit', 'N/A')}")
                print(f"Risk-Reward Ratio: {rec.get('risk_reward_ratio', 'N/A')}")
                print(f"Position Size: {rec.get('position_sizing_percentage', 'N/A')}%")
                print(f"Timeframe: {rec.get('timeframe', 'N/A')}")
                print(f"Confidence: {rec.get('confidence', 'N/A')}")

        print("\n" + "="*80)
        print("RISK MANAGEMENT PLAN SUMMARY")
        print("="*80)
        if 'overall_plan' in self.risk_management:
            print(self.risk_management['overall_plan'])
        else:
            print("No risk management plan available.")

        print("\n" + "="*80)
        print("CONCLUSION")
        print("="*80)
        print("Charts have been saved as PNG files.")
        print("Review the recommendations and risk management plan before placing any trades.")
        print("Remember that all trading involves risk, and past performance is not indicative of future results.")


# Run the analysis
if __name__ == "__main__":
    trader = ForexTrader()
    trader.run_full_analysis()
# Out:
# Successfully fetched data for USDJPY
# Successfully fetched data for EURUSD
# Successfully fetched data for GBPUSD
# Successfully fetched data for AUDUSD
#
# Analyzing patterns for USDJPY...
# Analysis for USDJPY completed.
#
# Analyzing patterns for EURUSD...
# Analysis for EURUSD completed.
#
# Analyzing patterns for GBPUSD...
# Analysis for GBPUSD completed.
#
# Analyzing patterns for AUDUSD...
# Analysis for AUDUSD completed.
#
# Generating risk management plan...
# Risk management plan generated.
# Error plotting recommendation for USDJPY: could not convert string to float: '145.88 (Conservative) or 145.5780 (Aggressive)'
# Chart for USDJPY has been saved as USDJPY_chart.png
# Chart for EURUSD has been saved as EURUSD_chart.png
# Chart for GBPUSD has been saved as GBPUSD_chart.png
# Chart for AUDUSD has been saved as AUDUSD_chart.png
#
# ================================================================================
# FOREX TRADING STRATEGY SUMMARY
# ================================================================================
#
# USDJPY RECOMMENDATION:
# Action: BUY
# Strategy: Trend Following (Cautious, awaiting confirmation) or (Aggressive, current price)
# Entry Price: 145.88 (Conservative) or 145.5780 (Aggressive)
# Stop Loss: 144.45 (Conservative) or 145.37 (Aggressive)
# Take Profit: 146.18 (Conservative, TP1) or 146.48 (Conservative, TP2) or 146.18 (Aggressive, TP1) or 146.48 (Aggressive, TP2)
# Risk-Reward Ratio: 0.21 (Conservative, TP1) or 0.42 (Conservative, TP2) or 2.89 (Aggressive, TP1) or 4.34 (Aggressive, TP2)
# Position Size: 2.0%
# Timeframe: short-term
# Confidence: medium
#
# EURUSD RECOMMENDATION:
# Action: SELL
# Strategy: Short on a pullback
# Entry Price: 1.12
# Stop Loss: 1.129
# Take Profit: 1.105
# Risk-Reward Ratio: 1.67
# Position Size: 2.0%
# Timeframe: medium-term
# Confidence: medium
#
# GBPUSD RECOMMENDATION:
# Action: SELL
# Strategy: Cautious Trend Following/Breakout (with a bearish bias)
# Entry Price: 1.325
# Stop Loss: 1.332
# Take Profit: 1.3135
# Risk-Reward Ratio: 1.64
# Position Size: 2.0%
# Timeframe: short-term
# Confidence: medium
#
# AUDUSD RECOMMENDATION:
# Action: BUY
# Strategy: Mean-reversion/breakout hybrid strategy, focusing on a potential bounce off support with a possible breakout of the 20-day SMA.
# Entry Price: 0.6403
# Stop Loss: 0.631
# Take Profit: 0.649
# Risk-Reward Ratio: 0.94
# Position Size: 0.21%
# Timeframe: short-term
# Confidence: low
#
# ================================================================================
# RISK MANAGEMENT PLAN SUMMARY
# ================================================================================
# Okay, here's a comprehensive risk management plan based on the provided forex trading recommendations and the PNP strategy rules. This plan prioritizes capital preservation and consistent profitability over aggressive gains.
#
# **Forex Trading Risk Management Plan**
#
# **I. General Principles**
#
# *   **Capital Preservation:** The primary goal is to protect trading capital. Risk management rules will be strictly adhered to.
# *   **Discipline:**  All trades must align with the PNP strategy rules and the risk management plan.  Emotional decision-making is strictly prohibited.
# *   **Adaptability:** The forex market is dynamic. This plan will be reviewed and adjusted as necessary, based on market conditions and performance.
# *   **Documentation:**  All trades will be documented, including entry reasons, trade management decisions, and outcomes. This data will be used for performance analysis and strategy refinement.
#
# **II. Portfolio Risk Management**
#
# 1.  **Maximum Portfolio Risk Percentage:**
#     *   **2% of Total Trading Capital at Risk per Trade, Max 3 Trades Open At The Same Time.** This means the total amount risked across ALL open positions cannot exceed 2% of your total trading capital.
#
# 2.  **Maximum Correlated Exposure:**
#     *   **3% of Total Capital in Correlated Pairs.**  Correlation refers to how closely pairs move in the same or opposite directions.  For example, EURUSD and GBPUSD are often positively correlated. Since the recommended trades involve selling both EURUSD and GBPUSD, their combined risk exposure cannot exceed 3% of total capital. If you take one of the trades that utilizes the full 2%, then the maximum risk you can utilize on the other trade is 1% .
#
# 3.  **Account Segregation:**
#     *   **Dedicated Trading Account:** Use a dedicated trading account solely for forex trading to avoid commingling funds.
#     *   **Regular Monitoring:** Monitor account balances and margin levels daily.
#
# **III. Position Sizing**
#
# 1.  **Basic Formula:**  Calculate position size based on the following formula:
#
#     *   `Position Size = (Risk per Trade Amount) / (Stop Loss in Pips * Pip Value)`
#     *   `Risk per Trade Amount = (Portfolio Size) * (Risk Percentage per Trade)`
#
# 2.  **Pip Value:**  Pip value depends on the currency pair and lot size. Obtain this information from your broker.
#
# 3.  **Conservative vs. Aggressive:** The recommendations offer both conservative and aggressive entries and stop losses. Choose *one* approach and stick to it consistently. Conservative is generally recommended for beginners.
#
# 4.  **Position Sizing Examples (Assuming a $10,000 Account):**
#
#     *   **USDJPY (Conservative Entry, $200 Risk):**
#         *   Risk per Trade Amount: $10,000 * 0.02 = $200
#         *   Stop Loss: 145.88 - 144.45 = 1.43 JPY  (143 pips)
#         *   Pip Value (USDJPY): Let's assume $0.09 per micro lot (check with broker).
#         *   Position Size: $200 / (143 pips * $0.09) = 15.5 micro lots. Round down to 15 micro lots.
#
#     *   **EURUSD (Entry 1.12, $200 Risk):**
#         *   Risk per Trade Amount: $200
#         *   Stop Loss: 1.129 - 1.12 = 0.009 (90 pips)
#         *   Pip Value (EURUSD): Let's assume $0.10 per micro lot (check with broker).
#         *   Position Size: $200 / (90 pips * $0.10) = 22.2 micro lots. Round down to 22 micro lots.
#
#     *   **GBPUSD (Entry 1.325, $200 Risk):**
#         *   Risk per Trade Amount: $200
#         *   Stop Loss: 1.332 - 1.325 = 0.007 (70 pips)
#         *   Pip Value (GBPUSD): Let's assume $0.10 per micro lot (check with broker).
#         *   Position Size: $200 / (70 pips * $0.10) = 28.5 micro lots. Round down to 28 micro lots.
#
#     *   **AUDUSD (Entry 0.6403, $200 Risk):**
#         *   Risk per Trade Amount: $200
#         *   Stop Loss: 0.6403 - 0.631 = 0.0093 (93 pips)
#         *   Pip Value (AUDUSD): Let's assume $0.10 per micro lot (check with broker).
#         *   Position Size: $200 / (93 pips * $0.10) = 21.5 micro lots. Round down to 21 micro lots.
#
#     * Ensure the calculated position size does not cause the total risk to exceed 2% of the account balance.
#
# **IV. Stop Loss Management**
#
# 1.  **Initial Stop Loss Placement:**
#
#     *   **USDJPY:** 144.45 (Conservative) or 145.37 (Aggressive)
#     *   **EURUSD:** 1.129
#     *   **GBPUSD:** 1.332
#     *   **AUDUSD:** 0.631
#     *   **Adherence to PNP Strategy:** Ensure the stop loss meets the PNP strategy requirements.  Specifically, ensure the risk-reward ratio is at least 1:1.5 *before* entering the trade. And that the candle is not bigger than 0.25% before entering.
#
# 2.  **Adjusting Stop Losses (Trailing Stop):**
#
#     *   **Move to Breakeven:** Once the price moves in your favor by an amount equal to the initial risk (e.g., if the initial risk was 100 pips, move the stop loss to breakeven after a 100-pip profit), move the stop loss to your entry point.
#     *   **Trailing Stop Based on Price Action:** As the price moves further in your favor, trail the stop loss based on significant support/resistance levels (for long positions, trail below significant support; for short positions, trail above significant resistance).
#     *   **EMA-Based Trailing Stop:**  Consider using a trailing stop based on the 200 EMA on a higher timeframe (e.g., 1-hour chart) to capture longer-term trends. Trail the stop loss just below the EMA for long positions, and just above the EMA for short positions.
#
# 3.  **Do Not Widen Stop Losses:** Under no circumstances should you widen your stop loss after entering a trade.
#
# **V. Profit Taking**
#
# 1.  **Partial Profit Taking:**
#
#     *   **At TP1 (50%):** Close 50% of the position when the price reaches TP1. This secures some profit and reduces overall risk.
#         *   **USDJPY:** 146.18 (Conservative & Aggressive)
#         *   **EURUSD:** Not listed.
#         *   **GBPUSD:** Not listed.
#         *   **AUDUSD:** Not listed.
#
#     *   **At TP2 (Remaining 50%):** Close the remaining 50% of the position when the price reaches TP2.
#         *   **USDJPY:** 146.48 (Conservative & Aggressive)
#
#     *   **Risk Free TP1 - EURUSD, GBPUSD, AUDUSD (50%)**: If your risk reward is above 1:2.0, close 50% of the position once you hit a 1:1 ratio.
#
# 2.  **Alternative Profit Taking (If no defined TP1/TP2):**
#
#     *   **Risk-Reward Ratio Target:** Aim for at least a 1:2 risk-reward ratio. If a clear price action level doesn't exist near TP2, aim for TP2. If there is price action at 1:1.5, aim for 1:1.5
#
# 3.  **Manual Closure:**  Be prepared to manually close positions if market conditions change rapidly or if the trade no longer aligns with the PNP strategy.
#
# **VI. Exit Strategy**
#
# 1.  **Stop Loss Hit:** The most basic exit. The trade idea was invalidated.
#
# 2.  **Take Profit Hit:** The ideal exit. The trade idea played out as planned.
#
# 3.  **Violation of PNP Strategy:**
#
#     *   If the trade setup invalidates (e.g., the 200 EMA on the 5-minute chart crosses the price in the opposite direction of your trade *after* you've entered), close the position.
#     *   If new, adverse economic data is released that significantly impacts the currency pair, close the position.
#
# 4.  **Time-Based Exit:**  If a trade is not progressing after a pre-determined period (e.g., 48 hours), consider closing it.  Stagnant trades can tie up capital. This should only be considered if the trade is still trending towards the target and has not shown any indication of going against the plan.
#
# 5.  **Weekend Risk:** Close all positions before the weekend to avoid potential gap risk.
#
# **VII. Loss Limits and Trading Pause**
#
# 1.  **Daily Loss Limit:** 3% of the Trading Account. If you lose 3% of your account balance in a single day, stop trading for the remainder of the day.
# 2.  **Weekly Loss Limit:** 5% of the Trading Account. If you lose 5% of your account balance in a single week, stop trading for the remainder of the week.
# 3.  **Monthly Loss Limit:** 8% of the Trading Account. If you lose 8% of your account balance in a single month, stop trading and re-evaluate your strategy.
# 4.  **Mandatory Review:** After hitting a daily/weekly/monthly loss limit, conduct a thorough review of your trading performance to identify the reasons for the losses and adjust your strategy accordingly.
#
# **VIII. Scaling In/Out of Positions**
#
# 1.  **Scaling In (Generally Discouraged):** Scaling into losing positions is prohibited.
# 2.  **Scaling Out (Encouraged):** Implement partial profit-taking as described in the "Profit Taking" section. Do not scale in until you hit TP1 (or other risk reduction metric).
# 3.  **Only scale in with a second position if:** the trend is confirmed to be intact.
#
# **IX. PNP Strategy Specific Rules Implementation**
#
# 1.  **Timeframe Confluence:** Strictly adhere to using the 200 EMA on both the 5-minute and 15-minute timeframes as outlined in the PNP strategy.
# 2.  **Pattern Recognition:**  Only enter trades based on confirmed Double Tops/Bottoms or Head & Shoulders/Inverted HNS patterns that meet the PNP criteria (V-shape in the center of double tops/bottoms, DCC confirmation for Head & Shoulders).
# 3.  **Entry Timing:**  Only enter trades between 10 AM and 10 PM (your local time zone).
# 4.  **200 EMA Proximity:**  Strictly avoid trades where the 200 EMA on the 5-minute or 15-minute timeframe is near the entry point, resulting in a risk-reward ratio below 1:1.5.
# 5.  **Risk-Reward Ratio:**  Always aim for a minimum risk-reward ratio of 1:1.5. The maximum stop loss should be 0.30% of the account balance.
# 6.  **EMA Pattern Formation:** Ensure Double Tops/Bottoms and Head & Shoulders patterns form *on* the EMA.
# 7.  **Entry Candle Size:** Avoid entering trades if the entry candle is larger than 0.25%.
# 8.  **Shoulder Candle Count:**  Ensure there are at least 7-8 candles in both shoulders of a Head & Shoulders/Inverted HNS pattern.
# 9.  **Target Proximity:** Avoid entry if the recent high or low is within 50% of the overall target.
#
# **X. Ongoing Monitoring and Review**
#
# 1.  **Daily Review:** Review all open positions and recent trades to ensure they still align with the PNP strategy and the risk management plan.
# 2.  **Weekly Review:** Analyze trading performance, identify areas for improvement, and adjust the strategy and risk management plan as needed.
# 3.  **Monthly Review:** Conduct a comprehensive review of trading performance, including win rate, risk-reward ratio, and overall profitability. Make adjustments to the strategy and risk management plan based on the results of the review. Backtest PNP on similar pairs.
# 4.  **Stay Informed:** Stay up-to-date on economic news and events that could impact the forex market. Adjust your trading strategy accordingly.
# 5.  **Adaptability:** The market is constantly changing. The plan must be able to adapt as market sentiment and indicators are known to change.
#
#
# ================================================================================
# CONCLUSION
# ================================================================================
# Charts have been saved as PNG files.
# Review the recommendations and risk management plan before placing any trades.
# Remember that all trading involves risk, and past performance is not indicative of future results.
